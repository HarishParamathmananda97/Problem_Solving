# %%
# Create nodes
# create linkedlist
# add nodes to linked list
# print linked list

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def insert(self, newNode):
        # head => John -> None
        if self.head is None:
            self.head = newNode
        else:
            # head=>John->Ben->None  || John -> Matthew
            lastNode = self.head 
            while True:
                if lastNode.next is None:
                    break
                lastNode = lastNode.next        
            lastNode.next = newNode
    
    def printList(self):
        # head => John->Ben->Matthew
        if self.head is None:
            print("List is Empty")
            return
        currentNode =  self.head
        while True:
            if currentNode is None:
                break
            print(currentNode.data)
            currentNode = currentNode.next

# node => data, next
# firstNode.data => John, firstNode.next => None
firstNode = Node("Harry")
linkedList = LinkedList()
linkedList.insert(firstNode)
secondNode = Node("Babji")
linkedList.insert(secondNode)
thirdNode = Node("Paramathmananda")
linkedList.insert(thirdNode)
linkedList.printList()
# Out:
# Harry
# Babji
# Paramathmananda

# %% [markdown]
# #### Insert a New Node as the head Node.
#
# """
# Program Logic:
# * Preserve the current head node in a temporary node.
# * Make the new node as the head node.
# * Make the next of your new node point to the temporary node.
# """

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def insertList(self, newNode):
        if self.head is None:
            self.head = newNode
        else:
            LastNode = self.head
            while True:
                if LastNode.next is None:
                    break
                LastNode = LastNode.next
            LastNode.next = newNode
            
    def printList(self):
        if self.head is None:
            print("list is empty")
            return
        currentNode = self.head
        while True:
            if currentNode is None:
                break
            print(currentNode.data)
            currentNode = currentNode.next
            
                

    
firstNode = Node('Harry')
linkedList = LinkedList()
linkedList.insertList(firstNode)
secondNode = Node('Balaji')
linkedList.insertList(secondNode)
thirdNode = Node('paramathmananda')
linkedList.insertList(thirdNode)
linkedList.printList()
# Out:
# Harry
# Balaji
# paramathmananda

# %% [markdown]
# # singleLinkedLIst.py with insert on head node

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList():
    def __init__(self):
        self.head = None
    
    def insertHead(self, newNode):
        # data => Matthew, next => None
        temporaryNode = self.head # Harry
        self.head = newNode # Jayanthi
        self.head.next = temporaryNode
        del temporaryNode 
        
    def insertEnd(self, newNode):
        if self.head is None:
            self.head = newNode
        else:
            lastNode = self.head
            while True:
                if lastNode.next is None:
                    break
                lastNode = lastNode.next
            lastNode.next = newNode
    
    def printList(self):
        if self.head is None:
            print("List is empty")
            return
        currentNode = self.head 
        while True:
            if currentNode is None:
                break
            print(currentNode.data)
            currentNode = currentNode.next

firstNode = Node("JHarish")
linkedList = LinkedList()
linkedList.insertEnd(firstNode)
secondNode = Node("Paramathmananda")
linkedList.insertEnd(secondNode)
thirdNode = Node("Jayanthi")
linkedList.insertHead(thirdNode)
linkedList.printList()
# Out:
# Jayanthi
# JHarish
# Paramathmananda

# %% [markdown]
# #### Insert a New Node in Between tWo Nodes.
#
# Program Logic:
# * Traverse the list till position 1
# * Store the details of previous node
# * Make a connection from the next of previous node to new node.
# * Make a connection from next of new node to node at position 1.
# * The new node now becomes your node at position 1 and the node that was earlier at position 1 now becomes the node at position 2.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None

    def insertat(self, newNode):
        tempNode = self.head
        self.head = newNode
        self.head.next = tempNode
        del tempNode

    def insertend(self, newNode):
        if self.head is None:
            self.head = newNode
        else:
            currentNode = self.head 
            while True:
                if currentNode.next is None:
                    break
                currentNode = currentNode.next
            currentNode.next = newNode

    def printNode(self):
        if self.head is None:
            print("Node is EMPTY.")
        else:
            currentNode = self.head
            while True:
                if currentNode is None:
                    break
                print(currentNode.data)
                currentNode = currentNode.next
            

# declaration
firstNode = Node('Harish')
linkedList = LinkedList()
linkedList.insertend(firstNode)
secondNode = Node('Babji')
linkedList.insertend(secondNode)
thirdNode = Node('paramathmananda')
linkedList.insertat(thirdNode)
linkedList.printNode()
# Out:
# paramathmananda
# Harish
# Babji

# %% [markdown]
# Insert a new Node in between two nodes
#
# Program Logic:
#
# * Traverse the list till position 1.
# * Store the details of previous node.
# * Make a connection from the next of previous node to new Node.
# * Make a connection from next of new Node to node at position 1.
# * New node now becomes your node at position 1 nad the node that was earlier at positioni 1 now becomes the node at position 2.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def insertat(self, newNode):
        tempNode = self.head
        self.head = newNode
        self.head.next = tempNode
        del tempNode

    def insertend(self, newNode):
        if self.head is None:
            self.head = newNode
        
        else:
            currentNode = self.head
            while True:
                if currentNode.next is None:
                    break
                currentNode = currentNode.next
            currentNode.next = newNode
    def listLength(self):
        length = 0
        currentNode = self.head
        while True:
            if currentNode is None:
                break
            length += 1
            currentNode = currentNode.next
        return length


    def insertatposition(self, newNode, position):
        currentNode = self.head
        currentPosition = 0
        if position <0 or position > self.listLength():
            print("Invalid Position")
            return
        if position == 0:
            self.insertat(newNode)
            return
        while True:
            if currentPosition == position:
                previousNode.next = newNode
                newNode.next = currentNode
                break
            previousNode = currentNode
            currentNode = currentNode.next
            currentPosition += 1




    def printList(self):
        if self.head is None:
            print("Node is Empty.")
        else:
            currentNode = self.head
            while True:
                if currentNode is None:
                    break
                print(currentNode.data)
                currentNode = currentNode.next
    
firstNode = Node(10)
linkedList = LinkedList()
linkedList.insertend(firstNode)
secondNode = Node(20)
linkedList.insertend(secondNode)
thirdNode = Node(15)
linkedList.insertatposition(thirdNode, 13)
linkedList.printList()
# Out:
# Invalid Position
# 10
# 20

# %%
"""Write a LinkedList to Insert at position, start and end."""
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
    
class LinkedList:
    def __init__(self):
        self.head = None
    def insertHead(self, newNode):
        tempNode = self.head
        self.head = newNode
        self.head.next = tempNode
        del tempNode

    def insertEnd(self, newNode):
        if self.head is None:
            self.head = newNode
        else:
            currentNode = self.head
            while True:
                if currentNode.next is None:
                    break
                currentNode = currentNode.next
            currentNode.next = newNode
    def linkedListLengthFinder(self):
        currentNode = self.head
        length = 0
        while currentNode is not None:
            currentNode = currentNode.next
            length += 1
        return length
        

    def insertatposition(self, newNode, position):
        if position == 0:
            self.insertHead(newNode)
            return
        if self.linkedListLengthFinder() < position:
            print("You have entered out of range number.")
            return
        currentNode = self.head
        currentPosition = 0
        while True:
            if currentPosition == position:
                previousNode.next = newNode
                newNode.next = currentNode
                break
            previousNode = currentNode
            currentNode = currentNode.next
            currentPosition += 1

    def printList(self):
        currentNode = self.head
        if currentNode is None:
            print("emtpy List.")
            return
        while True:
            if currentNode is None:
                break
            print(currentNode.data)
            currentNode = currentNode.next

firstNode = Node(10)
linkedList = LinkedList()
linkedList.insertEnd(firstNode)
secondNode = Node(20)
linkedList.insertEnd(secondNode)
thirdNode = Node(15)
linkedList.insertatposition(thirdNode, 1)
fourthNode = Node(5)
linkedList.insertHead(fourthNode)
linkedList.printList()
# Out:
# 5
# 10
# 15
# 20

# %% [markdown]
# Delete a Node from the end of the list
# Program Logic:
# * Traverse till the end of the list.
# * Preserver the last second node in a temporary Node.
# * Delete the last Node.
# * Make the next of the temporary node point ot None.

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
class LinkedList:
    def __init__(self):
        self.head = None

    def inserthead(self, newNode):
        tempNode = self.head 
        self.head = newNode
        self.head.next = tempNode 
        del tempNode

    def insertend(self, newNode):
        if self.head == None:
            self.head = newNode

        else:
            currentNode = self.head 
            while True:
                if currentNode.next == None:
                    break
                currentNode = currentNode.next
            currentNode.next = newNode
    def lengthlink(self):
        length = 0
        while True:
            currentNode = self.head 
            if currentNode == None:
                break
            currentNode = currentNode.next
            length += 1
        return length
    def insertat(self, newNode, position):
        if position > self.lengthlink():
            print("Invalid Position")
            return
        if position is 0:
            self.insertHead(newNode)
            return

        currentNode = self.head
        currentPosition = 0
        while True:
            if currentPosition == position:
                previousNode.next = newNode
                newNode.next = currentNode
                break
            previousNode = currentNode
            currentNode = currentNode.next
            currentPosition += 1
    def deleteEnd(self):
        lastNode = self.head
        while lastNode.next is not None:
            previousNode = lastNode
            lastNode = lastNode.next
        previousNode.next = None

        
    def printList(self):
        if self.head is None:
            print("List is empty")
        else:
            currentNode = self.head 
            while True:
                if currentNode == None:
                    break
                print(currentNode.data)
                currentNode = currentNode.next
    
firstNode = Node('harish')
secondNode = Node('jayanthi')
thirdNode = Node('paramathmananda')
fourthNode = Node('abu')
linkedList = LinkedList()
linkedList.insertend(firstNode)
linkedList.insertend(secondNode)
linkedList.inserthead(thirdNode)
linkedList.insertat(fourthNode, 2)
linkedList.printList()
# Out:
# <>:39: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:39: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Harish Paramathma\AppData\Local\Temp\ipykernel_8060\1085220033.py:39: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if position is 0:

# %%
# Out:
# CDC ABC
# CDC BCD
# CDC CDC
# CDC DCD
# CDC CDC
# CDC DC
# 2
