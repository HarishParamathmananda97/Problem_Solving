# %%
# Import necessary libraries
import yfinance as yf

# Define the ticker symbol
ticker_symbol = 'AAPL'

# Get data on the specified ticker
ticker_data = yf.Ticker(ticker_symbol)

# Get the historical prices for the specified period
hist_data = ticker_data.history(period='1d', start='2020-01-01', end='2023-01-01')

# Display the historical data
hist_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-02 00:00:00-05:00   72.444306   73.510531   72.187536   73.449394
# 2020-01-03 00:00:00-05:00   72.666856   73.505647   72.507903   72.735329
# 2020-01-06 00:00:00-05:00   71.845172   73.354016   71.590842   73.314888
# 2020-01-07 00:00:00-05:00   73.324657   73.583875   72.747532   72.970070
# 2020-01-08 00:00:00-05:00   72.669286   74.449580   72.669286   74.143898
# ...                               ...         ...         ...         ...
# 2022-12-23 00:00:00-05:00  130.720412  132.218125  129.442364  131.658981
# 2022-12-27 00:00:00-05:00  131.179720  131.209673  128.523771  129.831772
# 2022-12-28 00:00:00-05:00  129.472318  130.830245  125.678116  125.847855
# 2022-12-29 00:00:00-05:00  127.794881  130.281083  127.535283  129.412415
# 2022-12-30 00:00:00-05:00  128.214246  129.751892  127.235737  129.731918
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Extract the 'Close' column from the historical data DataFrame
closing_prices = hist_data['Close']

# Plot the closing prices
plt.plot(closing_prices)

# Set the title and labels for the plot
plt.title('Apple Price')
plt.xlabel('Month - Year')
plt.ylabel('Closing Price')


# Display the plot
plt.show()

# %%
import numpy as np

# Create a new figure and set the size
plt.figure(figsize=(10, 6))

# Plot the closing prices with a blue solid line, markers, and a custom line width
plt.plot(closing_prices, color='blue', marker='o', linestyle='-', linewidth=1.5, label='AAPL Close Price')

# Set the title and labels for the plot
plt.title('Apple Inc. (AAPL) Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Customize x-axis ticks to display one tick per year
years = np.arange(closing_prices.index.min().year, closing_prices.index.max().year + 1)
tick_positions = [f'{year}-01-01' for year in years]
tick_labels = [str(year) for year in years]
plt.xticks(tick_positions, tick_labels)

# Customize y-axis ticks with a step of 50
y_tick_positions = np.arange(0, closing_prices.max() + 50, 50)
plt.yticks(y_tick_positions)

# Add a legend and grid
plt.legend()
plt.grid(True)

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd

# Create a new figure and set the size
plt.figure(figsize=(10, 6))

# Set the background color to purple
plt.gca().set_facecolor('purple')

# Plot the closing prices with a purple solid line, smaller markers, and a custom line width
plt.plot(closing_prices, color='lightblue', marker='o', markersize=3, linestyle='-', linewidth=1.5, label='AAPL Close Price')

# Set the title and labels for the plot
plt.title('Apple Inc. (AAPL) Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Customize x-axis ticks to display one tick per month
month_range = pd.date_range(closing_prices.index.min(), closing_prices.index.max(), freq='M')
tick_positions = month_range.strftime('%Y-%m-%d').tolist()
tick_labels = month_range.strftime('%Y-%m').tolist()
plt.xticks(tick_positions, tick_labels, rotation=90)

# Customize y-axis ticks with a step of 100
y_tick_positions = np.arange(0, closing_prices.max() + 100, 100)
plt.yticks(y_tick_positions)

# Add a legend and grid
plt.legend()
plt.grid(True)

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd

# Create a new figure and set the size
plt.figure(figsize=(10, 6))

# Set the background color to purple
plt.gca().set_facecolor('purple')

# Plot the closing prices with a white solid line, smaller markers, and a custom line width
plt.plot(closing_prices, color='white', marker='o', markersize=3, linestyle='-', linewidth=2, label='AAPL Close Price')

# Set the title and labels for the plot
plt.title('Apple Inc. (AAPL) Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Customize x-axis ticks to display one tick per month
month_range = pd.date_range(closing_prices.index.min(), closing_prices.index.max(), freq='M')
tick_positions = month_range.strftime('%Y-%m-%d').tolist()
tick_labels = month_range.strftime('%Y-%m').tolist()
plt.xticks(tick_positions, tick_labels, rotation=90)

# Customize y-axis ticks with a step of 100
y_tick_positions = np.arange(0, closing_prices.max() + 100, 100)
plt.yticks(y_tick_positions)

# Add a legend (no grid)
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd

# Create a new figure and set the size
plt.figure(figsize=(10, 6))

# Set the background color to purple
plt.gca().set_facecolor('purple')

# Plot the closing prices with a white solid line, smaller markers, and a custom line width
plt.plot(closing_prices, color='white', marker='o', markersize=3, linestyle='-', linewidth=2, label='AAPL Close Price')

# Find the index and values for the maximum and minimum closing prices
max_price_idx = closing_prices.idxmax()
max_price = closing_prices[max_price_idx]
min_price_idx = closing_prices.idxmin()
min_price = closing_prices[min_price_idx]

# Plot circles around the maximum and minimum closing prices
plt.scatter([max_price_idx, min_price_idx], [max_price, min_price], s=150, edgecolors='red', facecolors='none', linewidths=1.5)

# Set the title and labels for the plot
plt.title('Apple Inc. (AAPL) Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Customize x-axis ticks and y-axis ticks as before
month_range = pd.date_range(closing_prices.index.min(), closing_prices.index.max(), freq='M')
tick_positions = month_range.strftime('%Y-%m-%d').tolist()
tick_labels = month_range.strftime('%Y-%m').tolist()
plt.xticks(tick_positions, tick_labels, rotation=90)
y_tick_positions = np.arange(0, closing_prices.max() + 100, 100)
plt.yticks(y_tick_positions)

# Add a legend (no grid)
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd

# Calculate the percentage change in closing prices
percentage_change = closing_prices.pct_change() * 100

# Create a new figure and set the size
plt.figure(figsize=(10, 6))

# Set the background color to purple
plt.gca().set_facecolor('purple')

# Plot the percentage change with a white solid line, smaller markers, and a custom line width
plt.plot(percentage_change, color='white', marker='o', markersize=3, linestyle='-', linewidth=2, label='AAPL % Change')

# Set the title and labels for the plot
plt.title('Apple Inc. (AAPL) Closing Price Percentage Change')
plt.xlabel('Date')
plt.ylabel('Percentage Change')

# Customize x-axis ticks and y-axis ticks as before
month_range = pd.date_range(closing_prices.index.min(), closing_prices.index.max(), freq='M')
tick_positions = month_range.strftime('%Y-%m-%d').tolist()
tick_labels = month_range.strftime('%Y-%m').tolist()
plt.xticks(tick_positions, tick_labels, rotation=90)
y_tick_positions = np.arange(percentage_change.min() - 5, percentage_change.max() + 5, 5)
plt.yticks(y_tick_positions)

# Add a legend (no grid)
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd

# Resample the closing prices by month and calculate the percentage change
monthly_closing_prices = closing_prices.resample('M').last()
monthly_percentage_change = monthly_closing_prices.pct_change() * 100

# Create a new figure and set the size
plt.figure(figsize=(10, 6))

# Set the background color to purple
plt.gca().set_facecolor('purple')

# Plot the monthly percentage change with a white solid line, smaller markers, and a custom line width
plt.plot(monthly_percentage_change, color='white', marker='o', markersize=3, linestyle='-', linewidth=2, label='AAPL % Change (Monthly)')

# Set the title and labels for the plot
plt.title('Apple Inc. (AAPL) Monthly Closing Price Percentage Change')
plt.xlabel('Date')
plt.ylabel('Percentage Change')

# Customize x-axis ticks and y-axis ticks as before
month_range = pd.date_range(closing_prices.index.min(), closing_prices.index.max(), freq='M')
tick_positions = month_range.strftime('%Y-%m-%d').tolist()
tick_labels = month_range.strftime('%Y-%m').tolist()
plt.xticks(tick_positions, tick_labels, rotation=90)
y_tick_positions = np.arange(monthly_percentage_change.min() - 5, monthly_percentage_change.max() + 5, 5)
plt.yticks(y_tick_positions)

# Add a legend (no grid)
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd

# Define the bins for percentage change groups
bins = [-np.inf, -10, 0, 10, np.inf]

# Group the percentage changes into the specified buckets
grouped_percentage_change = pd.cut(monthly_percentage_change, bins)

# Calculate the count of each bucket
bucket_counts = grouped_percentage_change.value_counts().sort_index()

# Create the histogram
plt.figure(figsize=(10, 6))
plt.gca().set_facecolor('purple')
bucket_counts.plot(kind='bar', color='white', edgecolor='white', width=0.8)

# Set the title and labels for the histogram
plt.title('Apple Inc. (AAPL) Monthly Closing Price Percentage Change Histogram')
plt.xlabel('Percentage Change Group')
plt.ylabel('Frequency')

# Customize x-axis ticks
plt.xticks(range(len(bucket_counts.index)), ['<-10%', '-10% to 0%', '0% to 10%', '>10%'], rotation=0)

# Customize y-axis ticks
y_tick_positions = np.arange(0, bucket_counts.max() + 1, 1)
plt.yticks(y_tick_positions)

# Display the histogram
plt.show()

# %%
import numpy as np
import pandas as pd

# Define the bins for percentage change groups
bins = [-np.inf, -10, 0, 10, np.inf]

# Group the percentage changes into the specified buckets
grouped_percentage_change = pd.cut(monthly_percentage_change, bins)

# Calculate the count of each bucket
bucket_counts = grouped_percentage_change.value_counts().sort_index()

# Create the histogram
plt.figure(figsize=(10, 6))
plt.gca().set_facecolor('black')

# Use distinct colors for each bar
colors = ['red', 'orange', 'lime', 'blue']

# Plot the histogram with the specified colors and custom styling
ax = bucket_counts.plot(kind='bar', color=colors, edgecolor='white', width=0.8, alpha=0.8)

# Set the title and labels for the histogram
plt.title('Apple Inc. (AAPL) Monthly Closing Price Percentage Change Histogram', fontsize=16, fontweight='bold', color='white')
plt.xlabel('Percentage Change Group', fontsize=14, color='white')
plt.ylabel('Frequency', fontsize=14, color='white')

# Customize x-axis ticks
plt.xticks(range(len(bucket_counts.index)), ['<-10%', '-10% to 0%', '0% to 10%', '>10%'], rotation=0, fontsize=12, color='white')

# Customize y-axis ticks
y_tick_positions = np.arange(0, bucket_counts.max() + 1, 1)
plt.yticks(y_tick_positions, fontsize=12, color='white')

# Add grid lines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set the spines' color to white
for spine in ax.spines.values():
    spine.set_edgecolor('white')

# Display the histogram
plt.show()

# %%
import numpy as np
import pandas as pd

# Define the bins for percentage change groups
bins = [-np.inf, -10, 0, 10, np.inf]

# Group the percentage changes into the specified buckets
grouped_percentage_change = pd.cut(monthly_percentage_change, bins)

# Calculate the count of each bucket
bucket_counts = grouped_percentage_change.value_counts().sort_index()

# Create the histogram
plt.figure(figsize=(10, 6))
plt.gca().set_facecolor('black')

# Use distinct colors for each bar
colors = ['red', 'orange', 'lime', 'blue']

# Plot the histogram with the specified colors and custom styling
ax = bucket_counts.plot(kind='bar', color=colors, edgecolor='white', width=0.8, alpha=0.8)

# Set the title and labels for the histogram
plt.title('Apple Inc. (AAPL) Monthly Closing Price Percentage Change Histogram', fontsize=16, fontweight='bold', color='white')
plt.xlabel('Percentage Change Group', fontsize=14, color='white')
plt.ylabel('Frequency', fontsize=14, color='white')

# Customize x-axis ticks
plt.xticks(range(len(bucket_counts.index)), ['<-10%', '-10% to 0%', '0% to 10%', '>10%'], rotation=0, fontsize=12, color='white')

# Customize y-axis ticks
y_tick_positions = np.arange(0, bucket_counts.max() + 1, 1)
plt.yticks(y_tick_positions, fontsize=12, color='white')

# Add grid lines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set the spines' color to white
for spine in ax.spines.values():
    spine.set_edgecolor('white')

# Add a legend for the bars
ax.legend(['Frequency'], facecolor='black', edgecolor='white', fontsize=12)

# Display the histogram
plt.show()

# %%
import numpy as np
import pandas as pd

# Define the bins for percentage change groups
bins = [-np.inf, -10, 0, 10, np.inf]

# Group the percentage changes into the specified buckets
grouped_percentage_change = pd.cut(monthly_percentage_change, bins)

# Calculate the count of each bucket
bucket_counts = grouped_percentage_change.value_counts().sort_index()

# Create the histogram
plt.figure(figsize=(10, 6))
plt.gca().set_facecolor('black')

# Use distinct colors for each bar
colors = ['red', 'orange', 'lime', 'green']

# Plot the histogram with the specified colors and custom styling
ax = bucket_counts.plot(kind='bar', color=colors, edgecolor='white', width=0.8, alpha=0.8)

# Set the title and labels for the histogram
plt.title('Apple Inc. (AAPL) Monthly Closing Price Percentage Change Histogram', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Percentage Change Group', fontsize=14, color='red')
plt.ylabel('Frequency', fontsize=14, color='Black')

# Customize x-axis ticks
plt.xticks(range(len(bucket_counts.index)), ['Less than -10%', '-10% to 0%', '0% to 10%', 'Greator than 10%'], rotation=0, fontsize=12, color='black')

# Customize y-axis ticks
y_tick_positions = np.arange(0, bucket_counts.max() + 1, 1)
plt.yticks(y_tick_positions, fontsize=12, color='black')

# Add grid lines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set the spines' color to white
for spine in ax.spines.values():
    spine.set_edgecolor('white')

# Add a legend for the bars
ax.legend(['Frequency'], facecolor='white', edgecolor='white', fontsize=12)

# Display the histogram
plt.show()

# %%
import numpy as np
import pandas as pd

# Define the bins for percentage change groups
bins = [-np.inf, -10, 0, 10, np.inf]

# Group the percentage changes into the specified buckets
grouped_percentage_change = pd.cut(monthly_percentage_change, bins)

# Calculate the count of each bucket
bucket_counts = grouped_percentage_change.value_counts().sort_index()

# Create the histogram
plt.figure(figsize=(10, 6))
plt.gca().set_facecolor('white')

# Use distinct colors for each bar
colors = ['red', 'orange', 'lime', 'blue']

# Plot the histogram with the specified colors and custom styling
ax = bucket_counts.plot(kind='bar', color=colors, edgecolor='black', width=0.4, alpha=0.8)

# Set the title and labels for the histogram
plt.title('Apple Inc. (AAPL) Monthly Closing Price Percentage Change Histogram', fontsize=16, fontweight='bold', color='black')
plt.xlabel('Percentage Change Group', fontsize=14, color='black')
plt.ylabel('Frequency', fontsize=14, color='black')

# Customize x-axis ticks
plt.xticks(range(len(bucket_counts.index)), ['<-10%', '-10% to 0%', '0% to 10%', '>10%'], rotation=0, fontsize=12, color='black')

# Customize y-axis ticks
y_tick_positions = np.arange(0, bucket_counts.max() + 1, 1)
plt.yticks(y_tick_positions, fontsize=12, color='black')

# Add grid lines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Set the spines' color to black
for spine in ax.spines.values():
    spine.set_edgecolor('black')



# Display the histogram
plt.show()

# %%
import numpy as np
import pandas as pd

# Define the bins for percentage change groups
bins = [-np.inf, -10, 0, 10, np.inf]

# Group the percentage changes into the specified buckets
grouped_percentage_change = pd.cut(monthly_percentage_change, bins)

# Calculate the count of each bucket
bucket_counts = grouped_percentage_change.value_counts().sort_index()

# Create the pie chart
plt.figure(figsize=(10, 6))
colors = ['red', 'orange', 'lime', 'blue']
labels = ['<-10%', '-10% to 0%', '0% to 10%', '>10%']
explode = (0.1, 0, 0, 0)

# Plot the pie chart with the specified colors, labels, and explode settings
plt.pie(bucket_counts, colors=colors, labels=labels, explode=explode, autopct='%1.1f%%', startangle=90)

# Set the title for the pie chart
plt.title('Apple Inc. (AAPL) Monthly Closing Price Percentage Change Pie Chart', fontsize=16, fontweight='bold', color='black')

# Display the pie chart
plt.show()
