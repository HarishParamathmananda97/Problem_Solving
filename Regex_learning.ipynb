# %%
import re
# Regex learning

# Used for pattern matching or String matching

text_content = "One find day (2024-01-24) to (2024-01-30) we enjoyed the wonderful journey in the relationship"

# %%
"""
Quantifiers:
[abc] => a, b or c
[^abc] => anycharacter except a,b,c
[a-z] => a to z
[A-Z] => A to Z
[a-zA-Z] => a to z, A  to Z
[0-9] => 0 to 9


[ ]? => Occurs 0 or 1 times
[ ]+ => Occurs 1 or more times
[ ]* => Occurs 0 or more times
[ ]{n} => Occurs n times
[ ]{n, } => Occurs n or more times
[ ]{y, z} => Occurs atleast y times but less than z times

Regex MetaCharacters: \ tells comp. to treat following character s search character .eg: '+','.'
\d => [0-9]
\D => [^0-9]
\w => [a-zA-Z0-9]
\w => [^\w]
"""

# %%
var1 = int(input('Enter the number: '))
for i in range(var1):
    print(i)
    var2 = int(input('Enter the number: '))
    for j in range(var2):
        print(j)
